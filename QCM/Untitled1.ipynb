# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy import integrate

# %%
data_2=np.loadtxt("Data//G7_EC//cycCV.ocw", comments="#", unpack=False, skiprows=2)

# %%
voltage=data_2[:, 0] 
current=data_2[:, 1]
z_time=voltage/(50*1e-3) #scanner=50mV/s
plt.plot(z_time,current,linestyle='dashed')
plt.xlabel('time(s)')
plt.ylabel('current(A)')
# Out:
# Text(0, 0.5, 'current(A)')

# %%
z_time_above=data_2[:164, 0] 
current_above=data_2[:164, 1]
z_time_below=data_2[165:328,0]
current_below=data_2[165:328,1]
plt.plot(z_time_above,current_above,linestyle='dashed')
plt.plot(z_time_below,current_below,linestyle='dashed')
z_time_above[0]
#voltage_below[0]
def objective(z_time_below, a, b):
    return a * z_time_below + b
a, b = popt_1
#plt.plot(voltage_below[10:95],objective(voltage_below[10:95], a, b))
plt.plot(z_time_below[17:95],objective(z_time_below[17:95], a, b),label='baseline fit')
plt.plot(z_time_below,current_below,linestyle='dashed',label='data')
plt.legend(loc='best')
plt.xlabel('time(s)')
plt.ylabel('current(A)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6b314661c410> in <module>
#       9 def objective(z_time_below, a, b):
#      10     return a * z_time_below + b
# ---> 11 a, b = popt_1
#      12 #plt.plot(voltage_below[10:95],objective(voltage_below[10:95], a, b))
#      13 plt.plot(z_time_below[17:95],objective(z_time_below[17:95], a, b),label='baseline fit')
#
# NameError: name 'popt_1' is not defined

# %%
integrate.simpson(objective(z_time_below[17:95], a, b),z_time_below[17:95])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-26c27e73e702> in <module>
# ----> 1 integrate.simpson(objective(z_time_below[17:95], a, b),z_time_below[17:95])
#
# NameError: name 'a' is not defined

# %%
((3.629399373761863e-08)/(1.6*1e-18))/(1e12) #50*1e-3
# Out:
# 0.022683746086011643

# %%
plt.plot(z_time_below[12:120],current_below[12:120],linestyle='dashed')
plt.plot(z_time_below[17:95],objective(z_time_below[17:95], a, b),label='baseline fit')
plt.title(' Cyclic Voltametery Lower part')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-228b3f9e54b7> in <module>
#       1 plt.plot(z_time_below[12:120],current_below[12:120],linestyle='dashed')
# ----> 2 plt.plot(z_time_below[17:95],objective(z_time_below[17:95], a, b),label='baseline fit')
#       3 plt.title(' Cyclic Voltametery Lower part')
#
# NameError: name 'a' is not defined

# %%
def objective(voltage_above, c, d):
    return c * voltage_above + d
...
# curve fit
popt_2, _ = curve_fit(objective, voltage_above, current_above)
# summarize the parameter values
c, d = popt_2
#print('y = %.5f * x + %.5f' % (a, b))
print(popt)
plt.plot(voltage_above[15:95],objective(voltage_above[15:95], c, d))
plt.plot(voltage_above,current_above,linestyle='dashed')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e77b2a796d94> in <module>
#       3 ...
#       4 # curve fit
# ----> 5 popt_2, _ = curve_fit(objective, voltage_above, current_above)
#       6 # summarize the parameter values
#       7 c, d = popt_2
#
# NameError: name 'voltage_above' is not defined
